# %%
# Import libraries here
library(dplyr)
library(class)
library(MASS)
library(Hmisc)
library(klaR)
library(e1071)
library(kknn)
library(rpart)
library(lars)
library(stats)
library(leaps)
library(repr)
library(glmnet)
library('caret')


# Get the data
df_Base = '/Users/sam/All-Program/App-DataSet/Spark-Operations/diabetes_dataset/df_Base.csv/'
df_F1 = '/Users/sam/All-Program/App-DataSet/Spark-Operations/diabetes_dataset/df_F1.csv/'
df_F2 = '/Users/sam/All-Program/App-DataSet/Spark-Operations/diabetes_dataset/df_F2.csv/'

df_Diag1Diag2NaN_rmv_F1 = '/Users/sam/All-Program/App-DataSet/Spark-Operations/diabetes_dataset/df_Diag1Diag2NaN_rmv_F1.csv/'
df_Diag1Diag2NaN_rmv_F2 = '/Users/sam/All-Program/App-DataSet/Spark-Operations/diabetes_dataset/df_Diag1Diag2NaN_rmv_F2.csv/'


file_names <- list.files(path = df_F1, pattern = ".csv", full.names = TRUE)
dataF1_DF <- do.call(rbind,lapply(file_names, read.csv, header=TRUE))
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘MASS’
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
# Loading required package: lattice
# Loading required package: survival
# Loading required package: Formula
# Loading required package: ggplot2
#
# Attaching package: ‘Hmisc’
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, src, summarize
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, round.POSIXt, trunc.POSIXt, units
#
#
# Attaching package: ‘e1071’
#
# The following object is masked from ‘package:Hmisc’:
#
#     impute
#
# Loaded lars 1.2
#
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-5
#
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:kknn’:
#
#     contr.dummy
#
# The following object is masked from ‘package:survival’:
#
#     cluster

# %%
# Check the data if its looks alright
dataF1_DF = data.frame(dataF1_DF)
head(dataF1_DF)
# Out:
#   time_in_hospital num_lab_procedures num_procedures num_medications
# 1 1                41                 0               1
# 2 3                59                 0              18
# 3 2                11                 5              13
# 4 2                44                 1              16
# 5 1                51                 0               8
# 6 3                31                 6              16
#   number_outpatient number_emergency number_inpatient number_diagnoses
# 1 0                 0                0                1
# 2 0                 0                0                9
# 3 2                 0                1                6
# 4 0                 0                0                7
# 5 0                 0                0                5
# 6 0                 0                0                9
#   race            gender ⋯ rosiglitazone acarbose miglitol tolazamide insulin
# 1 Caucasian       Female ⋯ No            No       No       No         No
# 2 Caucasian       Female ⋯ No            No       No       No         Up
# 3 AfricanAmerican Female ⋯ No            No       No       No         No
# 4 Caucasian       Male   ⋯ No            No       No       No         Up
# 5 Caucasian       Male   ⋯ No            No       No       No         Steady
# 6 Caucasian       Male   ⋯ No            No       No       No         Steady
#   glyburide_metformin glipizide_metformin change diabetesMed readmitted
# 1 No                  No                  No     No          no
# 2 No                  No                  Ch     Yes         no
# 3 No                  No                  No     Yes         no
# 4 No                  No                  Ch     Yes         no
# 5 No                  No                  Ch     Yes         no
# 6 No                  No                  No     Yes         no

# %%
# Do some small sanity check to be sure your data looks the same way as dumped before.


# Check for numeric and factor columns and maatch them, if the are proper
numCol <- length(names(dataF1_DF))
print ('The Total number of featurer incluing the Label and ID columns are: ') 
numCol


# Check if the correct features are numeric, if not then convert them to numeric and vice-a-versa 
# c('time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses')
print ('All Nueric features interpreted by R are: ') 
names(which(sapply(dataF1_DF, is.numeric)))

# Check if the correct features are nominal, if not then convert them to factors and vice-a-versa
print ('All Factor features interpreted by R are: ') 
names(which(sapply(dataF1_DF, is.factor)))

# Converting the non-numeric columns into factors
dataF1_DF$admission_type_id <- as.factor(as.character(dataF1_DF$admission_type_id))
dataF1_DF$discharge_disposition_id <- as.factor(as.character(dataF1_DF$discharge_disposition_id))
dataF1_DF$admission_source_id <- as.factor(as.character(dataF1_DF$admission_source_id))

# Converting readmitted into 1 and 0 where 1=yes and 0=no
dataF1_DF$readmitted<- as.factor(ifelse(dataF1_DF$readmitted=="yes", 1, 0))

# Get the Numeric anf Factor features 
numericCols <- names(which(sapply(dataF1_DF, is.numeric)))
# numericCols <- numericCols[numericCols != 'id']              # Removind the ID column
factorCols <- names(which(sapply(dataF1_DF, is.factor)))

# Samity check
print ('All numeric columns after DataType Conversion are: ')
numericCols
print ('All factor columns after DataType Conversion are: ')
factorCols
# Out:
# [1] "The Total number of featurer incluing the Label and ID columns are: "
# [1] 39
# [1] "All Nueric features interpreted by R are: "
#  [1] "time_in_hospital"         "num_lab_procedures"
#  [3] "num_procedures"           "num_medications"
#  [5] "number_outpatient"        "number_emergency"
#  [7] "number_inpatient"         "number_diagnoses"
#  [9] "admission_type_id"        "discharge_disposition_id"
# [11] "admission_source_id"
# [1] "All Factor features interpreted by R are: "
#  [1] "race"                "gender"              "age"
#  [4] "medical_specialty"   "diag_1"              "diag_2"
#  [7] "diag_3"              "max_glu_serum"       "A1Cresult"
# [10] "metformin"           "repaglinide"         "nateglinide"
# [13] "chlorpropamide"      "glimepiride"         "glipizide"
# [16] "glyburide"           "tolbutamide"         "pioglitazone"
# [19] "rosiglitazone"       "acarbose"            "miglitol"
# [22] "tolazamide"          "insulin"             "glyburide_metformin"
# [25] "glipizide_metformin" "change"              "diabetesMed"
# [28] "readmitted"
# [1] "All numeric columns after DataType Conversion are: "
# [1] "time_in_hospital"   "num_lab_procedures" "num_procedures"
# [4] "num_medications"    "number_outpatient"  "number_emergency"
# [7] "number_inpatient"   "number_diagnoses"
# [1] "All factor columns after DataType Conversion are: "
#  [1] "race"                     "gender"
#  [3] "age"                      "admission_type_id"
#  [5] "discharge_disposition_id" "admission_source_id"
#  [7] "medical_specialty"        "diag_1"
#  [9] "diag_2"                   "diag_3"
# [11] "max_glu_serum"            "A1Cresult"
# [13] "metformin"                "repaglinide"
# [15] "nateglinide"              "chlorpropamide"
# [17] "glimepiride"              "glipizide"
# [19] "glyburide"                "tolbutamide"
# [21] "pioglitazone"             "rosiglitazone"
# [23] "acarbose"                 "miglitol"
# [25] "tolazamide"               "insulin"
# [27] "glyburide_metformin"      "glipizide_metformin"
# [29] "change"                   "diabetesMed"
# [31] "readmitted"

# %%
# Check if there are any Na's in the dataset

# %% [markdown]
# # Common Functions:

# %%
bindModel <- function(yLabel, xFeatures=NULL, featureSet=NULL){
    # Automates the creation of feature model to be passed into an Classifier or Predictive Model
    if (is.null(xFeatures)){
        xFeatures <- featureSet[featureSet != yLabel]
    }   
    return (as.formula(paste(yLabel, "~", paste(xFeatures, collapse = '+ '))))
}

factorMatrixBuilder <- function (dataFrameIN, numericCols, factorCols, yLabel){
    # Creates a design matrix by expanding the factors to a set of dummy variables and interaction etc.
    xNumeric <- dataFrameIN[, numericCols]
    xFactor <- dataFrameIN[, factorCols]
    
    factorModel <- bindModel(yLabel=yLabel, featureSet=factorCols)
    xFactor <- model.matrix(factorModel, data=xFactor)[, -1]        # -1 is provided to exclude the intercept term from the matrix

    return (as.matrix(data.frame(xNumeric, xFactor)))
}


stratifiedSampling <- function(dataIN, sample_on_col, trainPrcnt, seed){
  set.seed(seed)
  trainIndices <- createDataPartition(y=dataIN[[sample_on_col]], p=trainPrcnt, list=FALSE)
  trainData <- dataIN[trainIndices,]
  testData <- dataIN[-trainIndices,]
  
  stopifnot(nrow(trainData) + nrow(testData) == nrow(dataIN))
  return (list(trainData, testData))
}

# %% [markdown]
# # Statistics:
# -----------
#
# ## GLM-stats

# %%
getSummaryElements_glm <- function(model, alpha){
  inputSummary <- summary(model)
  inputSummary_DF <- as.data.frame(inputSummary$coefficients)  # z is for glm
  inputSummary_DF = inputSummary_DF[-1,]   # Remove the summary for intercept
  signFeatureIndice <- which(inputSummary_DF['Pr(>|z|)'] <= alpha)
  
  numFeatures <- nrow(inputSummary_DF) # -1 for the intercept
  numSignFeatures <- length(signFeatureIndice)

  # Get the top i significant features
  i <- 1
  topI_SignFeatures <- 0
  while (i<=3){
    
    if (nrow(inputSummary_DF) >= 1){    # only if the summary dataframe has elements
      # Remove the entry of the intercept term
      min_index <- which(inputSummary_DF['Pr(>|z|)'] == min(inputSummary_DF['Pr(>|z|)']) & inputSummary_DF['Pr(>|z|)'] <= alpha)
      min_index
      if (length(min_index)!=0){
        topI_SignFeatures[i] <- rownames(inputSummary_DF)[min_index]
        inputSummary_DF = inputSummary_DF[-min_index,]
      } else {
        topI_SignFeatures[i] <- NaN
      }
    } else {
      topI_SignFeatures[i] <- NaN
    }
    
    i <- i+1
  }

  # signFeatures <- row.names(inputSummary_DF[signFeatureIndice,])
  nullDeviance <- inputSummary$null
  residualDeviance <- inputSummary$deviance
  aic <- inputSummary$aic
  
  ## Residual Distribution:
  residuals <- resid(model)
  mean <- mean(residuals)
  min <- quantile(residuals)[['0%']]
  q1 <- quantile(residuals)[['25%']]
  median <- quantile(residuals)[['50%']]
  q3 <- quantile(residuals)[['75%']]
  max <- quantile(residuals)[['100%']]
  
  return (list(numFeatures=numFeatures, 
               numSignFeatures=numSignFeatures,
               topI_SignFeatures=topI_SignFeatures,
               nullDeviance=nullDeviance,
               residualDeviance=residualDeviance,
               aic=aic,
               resid_mean=mean,
               resid_min=min,
               resid_q1=q1,
               resid_median=median,
               resid_q3=q3,
               resid_max=max))
}


glmStats <- function(dataIN, max_p_val=0.20){
  cols <- colnames(dataIN)
  cols <- cols[1:length(cols)-1]   # removing readitted (the label from the list)
  
  # stats <- c('numCategories', 'numSignCategories', 'signF1','signF2', 'signF3', 'nullDeviance', 'residualDeviance', 'aic', 'mean(resid)','min(resid)','q1(resid)','median(resid)','q3(resid)','max(resid)')
  # dataOut <- data.frame(matrix(ncol = length(stats), nrow = length(cols)))
  # colnames(dataOut) <- stats
  # rownames(dataOut) <- cols
  # 
  # # Change the columns signF1, signF2 and signF3 into characters
  # dataOut$signF1 <- as.character(dataOut$signF1)
  # dataOut$signF2 <- as.character(dataOut$signF2)
  # dataOut$signF3 <- as.character(dataOut$signF3)

  dataOut <- data.frame()
  for (col in cols){
    modelF1.model <- bindModel(yLabel='readmitted', xFeatures=col)
    modelF1.glm <- glm(modelF1.model, family='binomial',data=dataIN)
    sumry <- getSummaryElements_glm(modelF1.glm, alpha=max_p_val)

    # Feature Statistics
    dataOut[col,'numCategories'] <- sumry[["numFeatures"]]
    dataOut[col,'numSignCategories'] <- sumry[["numSignFeatures"]]
    dataOut[col,'signF1'] <- sumry[["topI_SignFeatures"]][1]
    dataOut[col,'signF2'] <- sumry[["topI_SignFeatures"]][2]
    dataOut[col,'signF3'] <- sumry[["topI_SignFeatures"]][3]
    
    # Statistics
    dataOut[col,'nullDeviance'] <- sumry[['nullDeviance']]
    dataOut[col,'residualDeviance'] <- sumry[['residualDeviance']]
    dataOut[col,'aic'] <- sumry[['aic']]
    
    # Residual Statistics
    dataOut[col,'mean(resid)'] <- sumry[["resid_mean"]]
    dataOut[col,'min(resid)'] <- sumry[["resid_min"]]
    dataOut[col,'q1(resid)'] <- sumry[['resid_q1']]
    dataOut[col,'median(resid)'] <- sumry[['resid_median']]
    dataOut[col,'q3(resid)'] <- sumry[['resid_q3']]
    dataOut[col,'max(resid)'] <- sumry[['resid_max']]
    
    #     print ('################################################################################')
    #     print ('')
  }
  return (dataOut)
}

# %%
# Stratified Sampling
dataOut <- stratifiedSampling(dataIN=dataF1_DF, sample_on_col='readmitted', trainPrcnt=0.8, seed=45223)
trainData <- dataOut[[1]]
testData <- dataOut[[2]]

# %%
# GLM of each independent variable with the ddependent (response variable): Deviance Statics , Residual Statistics and Significance Statistics 
dataDF <- data.frame(subset(trainData, select = -c(diag_1,diag_2,diag_3)))
stats.glm <- glmStats(dataDF, max_p_val=0.10)
stats.glm
# Out:
#                          numCategories numSignCategories
# time_in_hospital          0             1
# num_lab_procedures        0             1
# num_procedures            0             0
# num_medications           0             1
# number_outpatient         0             1
# number_emergency          0             1
# number_inpatient          0             1
# number_diagnoses          0             1
# race                      4             1
# gender                    1             0
# age                       8             8
# admission_type_id         6             2
# discharge_disposition_id 19            13
# admission_source_id      14             4
# medical_specialty        66             3
# max_glu_serum             2             0
# A1Cresult                 2             0
# metformin                 2             0
# repaglinide               2             0
# nateglinide               2             0
# chlorpropamide            2             0
# glimepiride               2             0
# glipizide                 2             2
# glyburide                 2             0
# tolbutamide               0             0
# pioglitazone              2             0
# rosiglitazone             2             0
# acarbose                  1             0
# miglitol                  2             0
# tolazamide                0             0
# insulin                   2             2
# glyburide_metformin       2             0
# glipizide_metformin       0             0
# change                    0             1
# diabetesMed               0             1
#                          signF1
# time_in_hospital         time_in_hospital
# num_lab_procedures       num_lab_procedures
# num_procedures           NaN
# num_medications          num_medications
# number_outpatient        number_outpatient
# number_emergency         number_emergency
# number_inpatient         number_inpatient
# number_diagnoses         number_diagnoses
# race                     raceCaucasian
# gender                   NaN
# age                      age_80_90_
# admission_type_id        admission_type_id3
# discharge_disposition_id discharge_disposition_id22
# admission_source_id      admission_source_id3
# medical_specialty        medical_specialtyOtolaryngology
# max_glu_serum            NaN
# A1Cresult                NaN
# metformin                NaN
# repaglinide              NaN
# nateglinide              NaN
# chlorpropamide           NaN
# glimepiride              NaN
# glipizide                glipizideNo
# glyburide                NaN
# tolbutamide              NaN
# pioglitazone             NaN
# rosiglitazone            NaN
# acarbose                 NaN
# miglitol                 NaN
# tolazamide               NaN
# insulin                  insulinNo
# glyburide_metformin      NaN
# glipizide_metformin      NaN
# change                   changeNo
# diabetesMed              diabetesMedYes
#                          signF2
# time_in_hospital         NaN
# num_lab_procedures       NaN
# num_procedures           NaN
# num_medications          NaN
# number_outpatient        NaN
# number_emergency         NaN
# number_inpatient         NaN
# number_diagnoses         NaN
# race                     NaN
# gender                   NaN
# age                      age_70_80_
# admission_type_id        admission_type_id6
# discharge_disposition_id discharge_disposition_id3
# admission_source_id      admission_source_id7
# medical_specialty        medical_specialtyObstetricsandGynecology
# max_glu_serum            NaN
# A1Cresult                NaN
# metformin                NaN
# repaglinide              NaN
# nateglinide              NaN
# chlorpropamide           NaN
# glimepiride              NaN
# glipizide                glipizideSteady
# glyburide                NaN
# tolbutamide              NaN
# pioglitazone             NaN
# rosiglitazone            NaN
# acarbose                 NaN
# miglitol                 NaN
# tolazamide               NaN
# insulin                  insulinSteady
# glyburide_metformin      NaN
# glipizide_metformin      NaN
# change                   NaN
# diabetesMed              NaN
#                          signF3                      nullDeviance
# time_in_hospital         NaN                         33786.15
# num_lab_procedures       NaN                         33786.15
# num_procedures           NaN                         33786.15
# num_medications          NaN                         33786.15
# number_outpatient        NaN                         33786.15
# number_emergency         NaN                         33786.15
# number_inpatient         NaN                         33786.15
# number_diagnoses         NaN                         33786.15
# race                     NaN                         33786.15
# gender                   NaN                         33786.15
# age                      age_90_100_                 33786.15
# admission_type_id        NaN                         33786.15
# discharge_disposition_id discharge_disposition_id5   33786.15
# admission_source_id      admission_source_id20       33786.15
# medical_specialty        medical_specialtyPsychology 33786.15
# max_glu_serum            NaN                         33786.15
# A1Cresult                NaN                         33786.15
# metformin                NaN                         33786.15
# repaglinide              NaN                         33786.15
# nateglinide              NaN                         33786.15
# chlorpropamide           NaN                         33786.15
# glimepiride              NaN                         33786.15
# glipizide                NaN                         33786.15
# glyburide                NaN                         33786.15
# tolbutamide              NaN                         33786.15
# pioglitazone             NaN                         33786.15
# rosiglitazone            NaN                         33786.15
# acarbose                 NaN                         33786.15
# miglitol                 NaN                         33786.15
# tolazamide               NaN                         33786.15
# insulin                  NaN                         33786.15
# glyburide_metformin      NaN                         33786.15
# glipizide_metformin      NaN                         33786.15
# change                   NaN                         33786.15
# diabetesMed              NaN                         33786.15
#                          residualDeviance aic      mean(resid) min(resid)
# time_in_hospital         33612.81         33616.81 -0.1964922  -0.5743088
# num_lab_procedures       33720.52         33724.52 -0.1971957  -0.5409617
# num_procedures           33785.62         33789.62 -0.1976674  -0.4393293
# num_medications          33716.00         33720.00 -0.1971927  -0.6578504
# number_outpatient        33779.97         33783.97 -0.1976312  -0.7930266
# number_emergency         33755.94         33759.94 -0.1975671  -2.4553296
# number_inpatient         33360.46         33364.46 -0.1955750  -1.9759855
# number_diagnoses         33688.90         33692.90 -0.1969519  -0.5888266
# race                     33771.22         33783.22 -0.1975596  -0.4390756
# gender                   33785.16         33791.16 -0.1976603  -0.4357910
# age                      33643.05         33663.05 -0.1965973  -0.4778163
# admission_type_id        33765.63         33781.63 -0.1975007  -0.7585276
# discharge_disposition_id 32984.31         33026.31 -0.1926920  -1.1774100
# admission_source_id      33764.75         33796.75 -0.1974849  -0.5691561
# medical_specialty        33589.94         33725.94 -0.1956337  -0.9005166
# max_glu_serum            33781.29         33789.29 -0.1976373  -0.4782360
# A1Cresult                33776.56         33784.56 -0.1976006  -0.4379217
# metformin                33772.51         33780.51 -0.1975707  -0.4570397
# repaglinide              33767.60         33775.60 -0.1975160  -0.7195299
# nateglinide              33781.59         33789.59 -0.1975979  -0.4337990
# chlorpropamide           33784.66         33792.66 -0.1976523  -0.4336105
# glimepiride              33781.75         33789.75 -0.1976412  -0.5269468
# glipizide                33773.75         33781.75 -0.1975892  -0.5450774
# glyburide                33783.79         33791.79 -0.1976543  -0.4560476
# tolbutamide              33786.15         33790.15 -0.1976711  -0.4335223
# pioglitazone             33783.26         33791.26 -0.1976512  -0.5256431
# rosiglitazone            33782.70         33790.70 -0.1976401  -0.4635089
# acarbose                 33782.51         33788.51 -0.1976454  -0.7089632
# miglitol                 33785.77         33793.77 -0.1976647  -0.4335305
# tolazamide               33785.22         33789.22 -0.1976630  -0.4335751
# insulin                  33740.77         33748.77 -0.1973491  -0.4749218
# glyburide_metformin      33783.36         33791.36 -0.1976430  -0.9005166
# glipizide_metformin      33785.22         33789.22 -0.1976550  -0.4335392
# change                   33771.79         33775.79 -0.1975678  -0.4462039
# diabetesMed              33739.35         33743.35 -0.1973228  -0.4449277
#                          q1(resid)  median(resid) q3(resid)  max(resid)
# time_in_hospital         -0.4401211 -0.4144027    -0.4020652 2.286403
# num_lab_procedures       -0.4477717 -0.4312026    -0.4091806 2.302751
# num_procedures           -0.4342355 -0.4329704    -0.4317087 2.199721
# num_medications          -0.4422294 -0.4245447    -0.4103022 2.284178
# number_outpatient        -0.4315893 -0.4315893    -0.4315893 2.199961
# number_emergency         -0.4304676 -0.4304676    -0.4304676 2.202218
# number_inpatient         -0.4148933 -0.4148933    -0.4148933 2.233983
# number_diagnoses         -0.4600739 -0.4281837    -0.3983170 2.389659
# race                     -0.4390756 -0.4390756    -0.4247212 2.297415
# gender                   -0.4357910 -0.4309525    -0.4309525 2.201242
# age                      -0.4619079 -0.4336667    -0.3855539 2.731180
# admission_type_id        -0.4383249 -0.4383249    -0.4153932 2.257303
# discharge_disposition_id -0.4490397 -0.3809233    -0.3809233 2.670141
# admission_source_id      -0.4397102 -0.4397102    -0.4239380 2.242291
# medical_specialty        -0.4426746 -0.4407248    -0.3970699 2.767180
# max_glu_serum            -0.4320358 -0.4320358    -0.4320358 2.199064
# A1Cresult                -0.4379217 -0.4379217    -0.4172545 2.240032
# metformin                -0.4388784 -0.4388784    -0.4129799 2.283183
# repaglinide              -0.4324796 -0.4324796    -0.4324796 2.198173
# nateglinide              -0.4337990 -0.4337990    -0.4337990 2.255759
# chlorpropamide           -0.4336105 -0.4336105    -0.4336105 2.388569
# glimepiride              -0.4337937 -0.4337937    -0.4337937 2.225450
# glipizide                -0.4309790 -0.4309790    -0.4309790 2.201189
# glyburide                -0.4318637 -0.4318637    -0.4318637 2.199410
# tolbutamide              -0.4335223 -0.4335223    -0.4335223 2.229308
# pioglitazone             -0.4341487 -0.4341487    -0.4341487 2.219957
# rosiglitazone            -0.4335140 -0.4335140    -0.4335140 2.620681
# acarbose                 -0.4336913 -0.4336913    -0.4336913 2.388569
# miglitol                 -0.4335305 -0.4335305    -0.4335305 2.229308
# tolazamide               -0.4335751 -0.4335751    -0.4335751 2.537272
# insulin                  -0.4388644 -0.4151931    -0.4151931 2.233364
# glyburide_metformin      -0.4336459 -0.4336459    -0.4336459 2.236252
# glipizide_metformin      -0.4335392 -0.4335392    -0.4335392 2.196048
# change                   -0.4462039 -0.4229001    -0.4229001 2.217550
# diabetesMed              -0.4449277 -0.4449277    -0.3954636 2.274811

# %%
col = c('age'
modelF1.model <- bindModel(yLabel='readmitted', xFeatures=col)
print (modelF1.model)
modelF1.glm <- glm(modelF1.model, family='binomial', data=trainData)
print (summary(modelF1.glm))
# Out:
# readmitted ~ age
# <environment: 0x7fbe71356c28>
#
# Call:
# glm(formula = modelF1.model, family = "binomial", data = trainData)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.4778  -0.4619  -0.4337  -0.3856   2.7312
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -3.7054     0.5822  -6.365 1.95e-10 ***
# age_10_20_    0.7915     0.6238   1.269  0.20450
# age_20_30_    1.2582     0.5950   2.115  0.03445 *
# age_30_40_    1.1587     0.5880   1.971  0.04878 *
# age_40_50_    1.1791     0.5844   2.017  0.04365 *
# age_50_60_    1.1435     0.5835   1.960  0.05002 .
# age_60_70_    1.3887     0.5830   2.382  0.01722 *
# age_70_80_    1.5213     0.5828   2.610  0.00905 **
# age_80_90_    1.5928     0.5832   2.731  0.00631 **
# age_90_100_   1.4620     0.5892   2.481  0.01309 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 33786  on 55970  degrees of freedom
# Residual deviance: 33643  on 55961  degrees of freedom
# AIC: 33663
#
# Number of Fisher Scoring iterations: 5

# %%
# Loop through individual columns and perform glm  
# We remove the diag_1, diag_2 and diag_3 columns as they have many many categorical. We Will come to them later.
dataDF <- data.frame(subset(trainData, select = -c(diag_1,diag_2,diag_3)))
cols = c('age', 'time_in_hospital')     
for (col in cols){
  print (col)
  modelF1.model <- bindModel(yLabel='readmitted', xFeatures=col)
  print (modelF1.model)
  modelF1.glm <- glm(modelF1.model, family='binomial',data=dataDF)
  print (summary(modelF1.glm))
  print ('################################################################################')
  print ('')
}
# Out:
# [1] "age"
# readmitted ~ age
# <environment: 0x7fbe734ae600>
#
# Call:
# glm(formula = modelF1.model, family = "binomial", data = dataDF)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.4778  -0.4619  -0.4337  -0.3856   2.7312
#
# Coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  -3.7054     0.5822  -6.365 1.95e-10 ***
# age_10_20_    0.7915     0.6238   1.269  0.20450
# age_20_30_    1.2582     0.5950   2.115  0.03445 *
# age_30_40_    1.1587     0.5880   1.971  0.04878 *
# age_40_50_    1.1791     0.5844   2.017  0.04365 *
# age_50_60_    1.1435     0.5835   1.960  0.05002 .
# age_60_70_    1.3887     0.5830   2.382  0.01722 *
# age_70_80_    1.5213     0.5828   2.610  0.00905 **
# age_80_90_    1.5928     0.5832   2.731  0.00631 **
# age_90_100_   1.4620     0.5892   2.481  0.01309 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 33786  on 55970  degrees of freedom
# Residual deviance: 33643  on 55961  degrees of freedom
# AIC: 33663
#
# Number of Fisher Scoring iterations: 5
#
# [1] "################################################################################"
# [1] ""
# [1] "time_in_hospital"
# readmitted ~ time_in_hospital
# <environment: 0x7fbe734d96a8>
#
# Call:
# glm(formula = modelF1.model, family = "binomial", data = dataDF)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -0.5743  -0.4401  -0.4144  -0.4021   2.2864
#
# Coefficients:
#                  Estimate Std. Error z value Pr(>|z|)
# (Intercept)      -2.60074    0.02662  -97.70   <2e-16 ***
# time_in_hospital  0.06300    0.00467   13.49   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 33786  on 55970  degrees of freedom
# Residual deviance: 33613  on 55969  degrees of freedom
# AIC: 33617
#
# Number of Fisher Scoring iterations: 5
#
# [1] "################################################################################"
# [1] ""

# %% [markdown]
# # Feature Selection
# --------
# ## R Square
#
# ## AIC

# %%
modelF1.model <- bindModel(yLabel='readmitted', featureSet=names(dataF1_DF))
modelF1.model
modelF1.glm <- glm(modelF1.model, data=dataF1_DF)
# Out:
# readmitted ~ time_in_hospital + num_lab_procedures + num_procedures +
#     num_medications + number_outpatient + number_emergency +
#     number_inpatient + number_diagnoses + race + gender + age +
#     admission_type_id + discharge_disposition_id + admission_source_id +
#     medical_specialty + diag_1 + diag_2 + diag_3 + max_glu_serum +
#     A1Cresult + metformin + repaglinide + nateglinide + chlorpropamide +
#     glimepiride + glipizide + glyburide + tolbutamide + pioglitazone +
#     rosiglitazone + acarbose + miglitol + tolazamide + insulin +
#     glyburide_metformin + glipizide_metformin + change + diabetesMed
# <environment: 0x7ff520ed9188>
# Warning message in Ops.factor(y, mu):
# “‘-’ not meaningful for factors”Warning message in Ops.factor(eta, offset):
# “‘-’ not meaningful for factors”Warning message in Ops.factor(y, mu):
# “‘-’ not meaningful for factors”

# %%
modelF1.AIC <- step(modelF1.glm, direction=c('both'),steps=10)
summary(modelF1.AIC)

# %% [markdown]
# # Model 1 : Implementing Lasso Regression:

# %%
Questions to ask for:
    1. Should we standarize ordinal datatypes
    2. Some features have more than 500 categories would, it be wise to put them to different levels, because the algorithm takes longer time to converge.
    3. Is there a way to understand (or a rule of thumb) if interactions or polynomial fit for some columns would improve the model accuracy.
    4. How to handle missing data, if 2000 records are missing (diad_1, diag_2, diag_3)
    5. Should we perform AIC and BIC on the full datset or only the train dataset.

# %%
# Build the design matrix by expanding the factor variables into dummy variables
dataMatrix <- factorMatrixBuilder(dataFrameIN=trainData, numericCols=numericCols, factorCols=factorCols, yLabel='readmitted')
head(dataMatrix)
print ('The number of instances are: ')
nrow(dataMatrix)
print ('The number of columns are; ')
ncol(dataMatrix)
label <- trainData$readmitted
# Out:
#   time_in_hospital num_lab_procedures num_procedures num_medications
# 1 1                41                 0               1
# 2 3                59                 0              18
# 3 2                11                 5              13
# 4 2                44                 1              16
# 5 1                51                 0               8
# 6 3                31                 6              16
#   number_outpatient number_emergency number_inpatient number_diagnoses
# 1 0                 0                0                1
# 2 0                 0                0                9
# 3 2                 0                1                6
# 4 0                 0                0                7
# 5 0                 0                0                5
# 6 0                 0                0                9
#   raceAsian raceCaucasian ⋯ tolazamideSteady insulinNo insulinSteady insulinUp
# 1 0         1             ⋯ 0                1         0             0
# 2 0         1             ⋯ 0                0         0             1
# 3 0         0             ⋯ 0                1         0             0
# 4 0         1             ⋯ 0                0         0             1
# 5 0         1             ⋯ 0                0         1             0
# 6 0         1             ⋯ 0                0         1             0
#   glyburide_metforminNo glyburide_metforminSteady glyburide_metforminUp
# 1 1                     0                         0
# 2 1                     0                         0
# 3 1                     0                         0
# 4 1                     0                         0
# 5 1                     0                         0
# 6 1                     0                         0
#   glipizide_metforminSteady changeNo diabetesMedYes
# 1 0                         1        0
# 2 0                         0        1
# 3 0                         1        1
# 4 0                         0        1
# 5 0                         0        1
# 6 0                         1        1
# [1] "The number of instances are: "
# [1] 44675
# [1] "The number of columns are; "
# [1] 2185

# %%
glmmod <- glmnet(x=dataMatrix, y=label, alpha=1, family="binomial")
# alpha = 1   for Lasso
# alpha = 0   for Ridge
# alpha = 0.5 for elastic Net

# %%
plot(glmmod, xvar="lambda")   # Plots the
# Out:
# plot without title

# %%
plot(glmmod)
# Out:
# plot without title

# %%
print(glmmod)
# DF : The number of non-zero coefficients
# %Dev : The percent of Null devience expained
# Lambda: The coefficient for the norm or the penalty coefficient
# Out:
# Call:  glmnet(x = dataMatrix, y = label, family = "binomial", alpha = 1)
#
#         Df       %Dev    Lambda
#  [1,]    0 -1.085e-14 7.088e-02
#  [2,]    1  2.592e-03 6.459e-02
#  [3,]    1  4.722e-03 5.885e-02
#  [4,]    2  6.640e-03 5.362e-02
#  [5,]    2  9.438e-03 4.886e-02
#  [6,]    2  1.179e-02 4.452e-02
#  [7,]    2  1.376e-02 4.056e-02
#  [8,]    2  1.543e-02 3.696e-02
#  [9,]    3  1.714e-02 3.368e-02
# [10,]    3  1.875e-02 3.068e-02
# [11,]    6  2.041e-02 2.796e-02
# [12,]    8  2.262e-02 2.547e-02
# [13,]    9  2.511e-02 2.321e-02
# [14,]    9  2.731e-02 2.115e-02
# [15,]   14  2.935e-02 1.927e-02
# [16,]   15  3.156e-02 1.756e-02
# [17,]   17  3.361e-02 1.600e-02
# [18,]   20  3.557e-02 1.458e-02
# [19,]   24  3.748e-02 1.328e-02
# [20,]   32  3.938e-02 1.210e-02
# [21,]   40  4.159e-02 1.103e-02
# [22,]   42  4.365e-02 1.005e-02
# [23,]   46  4.552e-02 9.155e-03
# [24,]   55  4.730e-02 8.342e-03
# [25,]   62  4.907e-02 7.601e-03
# [26,]   77  5.085e-02 6.925e-03
# [27,]   91  5.267e-02 6.310e-03
# [28,]  114  5.467e-02 5.750e-03
# [29,]  144  5.677e-02 5.239e-03
# [30,]  184  5.897e-02 4.773e-03
# [31,]  218  6.126e-02 4.349e-03
# [32,]  274  6.363e-02 3.963e-03
# [33,]  344  6.615e-02 3.611e-03
# [34,]  425  6.881e-02 3.290e-03
# [35,]  517  7.159e-02 2.998e-03
# [36,]  630  7.444e-02 2.732e-03
# [37,]  740  7.727e-02 2.489e-03
# [38,]  846  8.002e-02 2.268e-03
# [39,]  956  8.267e-02 2.066e-03
# [40,] 1048  8.518e-02 1.883e-03
# [41,] 1146  8.754e-02 1.715e-03
# [42,] 1259  8.975e-02 1.563e-03
# [43,] 1350  9.180e-02 1.424e-03
# [44,] 1426  9.368e-02 1.298e-03
# [45,] 1495  9.539e-02 1.182e-03
# [46,] 1545  9.692e-02 1.077e-03
# [47,] 1588  9.829e-02 9.817e-04
# [48,] 1628  9.950e-02 8.944e-04
# [49,] 1676  1.006e-01 8.150e-04
# [50,] 1720  1.015e-01 7.426e-04
# [51,] 1765  1.024e-01 6.766e-04
# [52,] 1806  1.031e-01 6.165e-04
# [53,] 1831  1.038e-01 5.617e-04
# [54,] 1857  1.044e-01 5.118e-04
# [55,] 1890  1.050e-01 4.664e-04
# [56,] 1903  1.054e-01 4.249e-04
# [57,] 1919  1.058e-01 3.872e-04
# [58,] 1948  1.062e-01 3.528e-04
# [59,] 1968  1.065e-01 3.214e-04
# [60,] 1979  1.068e-01 2.929e-04
# [61,] 1993  1.071e-01 2.669e-04
# [62,] 2001  1.073e-01 2.432e-04
# [63,] 2017  1.076e-01 2.216e-04
# [64,] 2020  1.077e-01 2.019e-04
# [65,] 2028  1.079e-01 1.839e-04
# [66,] 2036  1.081e-01 1.676e-04
# [67,] 2049  1.082e-01 1.527e-04
# [68,] 2055  1.083e-01 1.391e-04
# [69,] 2066  1.084e-01 1.268e-04
# [70,] 2073  1.085e-01 1.155e-04
# [71,] 2084  1.086e-01 1.053e-04
# [72,] 2089  1.087e-01 9.591e-05
# [73,] 2090  1.087e-01 8.739e-05
# [74,] 2093  1.088e-01 7.963e-05
# [75,] 2097  1.089e-01 7.255e-05
# [76,] 2105  1.089e-01 6.611e-05
# [77,] 2105  1.090e-01 6.023e-05
# [78,] 2110  1.090e-01 5.488e-05
# [79,] 2110  1.090e-01 5.001e-05
# [80,] 2115  1.091e-01 4.556e-05
# [81,] 2119  1.091e-01 4.152e-05
# [82,] 2123  1.091e-01 3.783e-05
# [83,] 2123  1.091e-01 3.447e-05
# [84,] 2128  1.092e-01 3.141e-05
# [85,] 2131  1.092e-01 2.862e-05
# [86,] 2131  1.092e-01 2.607e-05
# [87,] 2132  1.092e-01 2.376e-05
# [88,] 2133  1.092e-01 2.165e-05
# [89,] 2133  1.092e-01 1.972e-05
# [90,] 2135  1.093e-01 1.797e-05
# [91,] 2137  1.093e-01 1.637e-05
# [92,] 2138  1.093e-01 1.492e-05
# [93,] 2139  1.093e-01 1.359e-05

# %%
coef(glmmod,s=0.01)  
# This produces the coefficient of the features between the range [-s, s] here s is a sequence of lambdas. 
# Note coefficient that are very close to 0 contribute very less to the model hence have less significance very small. 
# Provided a value of s you can see the coefficient
# Out:
# 2186 x 1 sparse Matrix of class "dgCMatrix"
#                                                                   1
# (Intercept)                                           -1.232806e+00
# time_in_hospital                                       8.998080e-03
# num_lab_procedures                                     4.261023e-06
# num_procedures                                        -2.578047e-03
# num_medications                                        .
# number_outpatient                                      6.120159e-02
# number_emergency                                       2.075858e-01
# number_inpatient                                       3.780112e-01
# number_diagnoses                                       6.167940e-02
# raceAsian                                              .
# raceCaucasian                                          2.395605e-02
# raceHispanic                                           .
# racemissing                                           -8.867673e-02
# raceOther                                              .
# genderMale                                             .
# genderUnknown.Invalid                                  .
# age.10.20.                                             .
# age.20.30.                                             .
# age.30.40.                                             .
# age.40.50.                                             .
# age.50.60.                                             .
# age.60.70.                                             .
# age.70.80.                                             1.030969e-01
# age.80.90.                                             7.102510e-02
# age.90.100.                                            .
# admission_type_id2                                     .
# admission_type_id3                                    -4.928492e-02
# admission_type_id4                                     .
# admission_type_id5                                     .
# admission_type_id6                                     2.680408e-01
# admission_type_id7                                     .
# admission_type_id8                                     .
# discharge_disposition_id10                             .
# discharge_disposition_id12                             .
# discharge_disposition_id15                             .
# discharge_disposition_id16                             .
# discharge_disposition_id17                             .
# discharge_disposition_id18                             .
# discharge_disposition_id2                              .
# discharge_disposition_id22                             9.371926e-02
# discharge_disposition_id23                             .
# discharge_disposition_id24                             .
# discharge_disposition_id25                             .
# discharge_disposition_id27                             .
# discharge_disposition_id28                             .
# discharge_disposition_id3                              .
# discharge_disposition_id4                              .
# discharge_disposition_id5                              .
# discharge_disposition_id6                              3.363383e-02
# discharge_disposition_id7                              .
# discharge_disposition_id8                              .
# discharge_disposition_id9                              .
# admission_source_id10                                  .
# admission_source_id13                                  .
# admission_source_id14                                  .
# admission_source_id17                                  .
# admission_source_id2                                   .
# admission_source_id20                                  .
# admission_source_id25                                  .
# admission_source_id3                                   .
# admission_source_id4                                  -2.926690e-01
# admission_source_id5                                   .
# admission_source_id6                                  -2.533921e-01
# admission_source_id7                                   6.705507e-02
# admission_source_id8                                   .
# admission_source_id9                                   .
# medical_specialtyAnesthesiology                        .
# medical_specialtyAnesthesiology.Pediatric              .
# medical_specialtyCardiology                            .
# medical_specialtyDentistry                             .
# medical_specialtyEmergency.Trauma                      .
# medical_specialtyEndocrinology                         .
# medical_specialtyFamily.GeneralPractice                .
# medical_specialtyGastroenterology                      .
# medical_specialtyGynecology                            .
# medical_specialtyHematology                            .
# medical_specialtyHematology.Oncology                   .
# medical_specialtyInfectiousDiseases                    .
# medical_specialtyInternalMedicine                      .
# medical_specialtymissing                               .
# medical_specialtyNephrology                            1.172788e-02
# medical_specialtyNeurology                             .
# medical_specialtyObsterics.Gynecology.GynecologicOnco  .
# medical_specialtyObstetrics                            .
# medical_specialtyObstetricsandGynecology              -3.186831e-01
# medical_specialtyOncology                              .
# medical_specialtyOphthalmology                         .
# medical_specialtyOrthopedics                           .
# medical_specialtyOrthopedics.Reconstructive           -8.379942e-02
# medical_specialtyOsteopath                             .
# medical_specialtyOtolaryngology                        .
# medical_specialtyPediatrics                            .
# medical_specialtyPediatrics.CriticalCare               .
# medical_specialtyPediatrics.EmergencyMedicine          .
# medical_specialtyPediatrics.Endocrinology             -3.029930e-03
# medical_specialtyPediatrics.Hematology.Oncology        .
# medical_specialtyPediatrics.Neurology                  .
# medical_specialtyPediatrics.Pulmonology                .
# medical_specialtyPhysicalMedicineandRehabilitation     .
# medical_specialtyPhysicianNotFound                     .
# medical_specialtyPodiatry                              .
# medical_specialtyProctology                            .
# medical_specialtyPsychiatry                            .
# medical_specialtyPsychiatry.Child.Adolescent           .
# medical_specialtyPsychology                            .
# medical_specialtyPulmonology                           .
# medical_specialtyRadiology                             .
# medical_specialtyRheumatology                          .
# medical_specialtySurgeon                               .
# medical_specialtySurgery.Cardiovascular                .
# medical_specialtySurgery.Cardiovascular.Thoracic      -1.022288e-01
# medical_specialtySurgery.Colon.Rectal                  .
# medical_specialtySurgery.General                       .
# medical_specialtySurgery.Maxillofacial                 .
# medical_specialtySurgery.Neuro                         .
# medical_specialtySurgery.Pediatric                     .
# medical_specialtySurgery.Plastic                       .
# medical_specialtySurgery.PlasticwithinHeadandNeck      .
# medical_specialtySurgery.Thoracic                      .
# medical_specialtySurgery.Vascular                      .
# medical_specialtyUrology                               .
# medical_specialtyCardiology.Pediatric                  .
# medical_specialtyHospitalist                           .
# medical_specialtyNeurophysiology                       .
# medical_specialtyOutreachServices                      .
# medical_specialtyPathology                             .
# medical_specialtyRadiologist                           .
# medical_specialtySurgicalSpecialty                     .
# medical_specialtyDCPTEAM                               .
# medical_specialtyEndocrinology.Metabolism              .
# diag_1112                                              .
# diag_1115                                              .
# diag_1117                                              .
# diag_1135                                              .
# diag_1136                                              .
# diag_1141                                              .
# diag_1142                                              .
# diag_1145                                              .
# diag_1146                                              .
# diag_1149                                              .
# diag_1150                                              .
# diag_1151                                              .
# diag_1152                                              .
# diag_1153                                              .
# diag_1154                                              .
# diag_1155                                              .
# diag_1156                                              .
# diag_1157                                              .
# diag_1158                                              .
# diag_1161                                              .
# diag_1162                                              .
# diag_1163                                              .
# diag_1164                                              .
# diag_1170                                              .
# diag_1171                                              .
# diag_1172                                              .
# diag_1174                                              .
# diag_1180                                              .
# diag_1182                                              .
# diag_1183                                              .
# diag_1184                                              .
# diag_1185                                              .
# diag_1188                                              .
# diag_1189                                              .
# diag_1191                                              .
# diag_1192                                              .
# diag_1193                                              .
# diag_1194                                              .
# diag_1196                                              .
# diag_1197                                              .
# diag_1198                                              .
# diag_1199                                              .
# diag_1200                                              .
# diag_1201                                              .
# diag_1202                                              .
# diag_1203                                              .
# diag_1204                                              .
# diag_1205                                              .
# diag_1210                                              .
# diag_1211                                              .
# diag_1212                                              .
# diag_1214                                              .
# diag_1215                                              .
# diag_1216                                              .
# diag_1217                                              .
# diag_1218                                              .
# diag_1220                                              .
# diag_1223                                              .
# diag_1225                                              .
# diag_1226                                              .
# diag_1227                                              .
# diag_1228                                              .
# diag_1230                                              .
# diag_1233                                              .
# diag_1235                                              .
# diag_1237                                              .
# diag_1238                                              .
# diag_1239                                              .
# diag_1241                                              .
# diag_1242                                              .
# diag_1244                                              .
# diag_1245                                              .
# diag_1246                                              .
# diag_1250                                              .
# diag_1250.01                                           .
# diag_1250.02                                           .
# diag_1250.03                                           .
# diag_1250.1                                            .
# diag_1250.11                                           .
# diag_1250.12                                           .
# diag_1250.13                                           .
# diag_1250.2                                            .
# diag_1250.21                                           .
# diag_1250.22                                           .
# diag_1250.23                                           .
# diag_1250.3                                            .
# diag_1250.31                                           .
# diag_1250.32                                           .
# diag_1250.33                                           .
# diag_1250.4                                            .
# diag_1250.41                                           .
# diag_1250.42                                           .
# diag_1250.43                                           .
# diag_1250.5                                            .
# diag_1250.51                                           .
# diag_1250.52                                           .
# diag_1250.6                                            1.163581e-01
# diag_1250.7                                            7.165606e-02
# diag_1250.8                                            .
# diag_1250.81                                           .
# diag_1250.82                                           .
# diag_1250.83                                           .
# diag_1250.9                                            .
# diag_1250.92                                           .
# diag_1250.93                                           .
# diag_1251                                              .
# diag_1252                                              .
# diag_1253                                              .
# diag_1255                                              .
# diag_1261                                              .
# diag_1262                                              .
# diag_1263                                              .
# diag_1266                                              .
# diag_1272                                              .
# diag_1274                                              .
# diag_1275                                              .
# diag_1276                                              .
# diag_1277                                              .
# diag_1278                                             -2.788302e-01
# diag_1280                                              .
# diag_1281                                              .
# diag_1282                                              .
# diag_1283                                              .
# diag_1284                                              .
# diag_1285                                              .
# diag_1286                                              .
# diag_1287                                              .
# diag_1288                                              .
# diag_1289                                              .
# diag_1290                                              .
# diag_1291                                              .
# diag_1292                                              .
# diag_1293                                              .
# diag_1294                                              .
# diag_1295                                              .
# diag_1296                                              .
# diag_1297                                              .
# diag_1298                                              .
# diag_13                                                .
# diag_1300                                              .
# diag_1301                                              .
# diag_1303                                              .
# diag_1304                                              .
# diag_1305                                              .
# diag_1306                                              .
# diag_1307                                              .
# diag_1308                                              .
# diag_1309                                              .
# diag_131                                               .
# diag_1310                                              .
# diag_1311                                              .
# diag_1312                                              .
# diag_1320                                              .
# diag_1322                                              .
# diag_1323                                              .
# diag_1331                                              .
# diag_1332                                              .
# diag_1333                                              .
# diag_1335                                              .
# diag_1336                                              .
# diag_1337                                              .
# diag_1340                                              .
# diag_1341                                              .
# diag_1342                                              .
# diag_1344                                              .
# diag_1345                                              .
# diag_1346                                              .
# diag_1348                                              .
# diag_1349                                              .
# diag_135                                               .
# diag_1350                                              .
# diag_1351                                              .
# diag_1352                                              .
# diag_1353                                              .
# diag_1355                                              .
# diag_1357                                              .
# diag_1358                                              .
# diag_1359                                              .
# diag_1362                                              .
# diag_1368                                              .
# diag_1369                                              .
# diag_1374                                              .
# diag_1376                                              .
# diag_1378                                              .
# diag_1379                                              .
# diag_138                                               .
# diag_1380                                              .
# diag_1383                                              .
# diag_1384                                              .
# diag_1386                                              .
# diag_1394                                              .
# diag_1395                                              .
# diag_1396                                              .
# diag_1397                                              .
# diag_1398                                              .
# diag_1401                                              .
# diag_1402                                              .
# diag_1403                                              .
# diag_1404                                              .
# diag_141                                               .
# diag_1410                                              .
# diag_1411                                              .
# diag_1413                                              .
# diag_1414                                              .
# diag_1415                                              .
# diag_1416                                              .
# diag_142                                               .
# diag_1420                                              .
# diag_1421                                              .
# diag_1423                                              .
# diag_1424                                              .
# diag_1425                                              .
# diag_1426                                              .
# diag_1427                                              .
# diag_1428                                              2.732333e-01
# diag_1429                                              .
# diag_1430                                              .
# diag_1431                                              .
# diag_1432                                              .
# diag_1433                                              .
# diag_1434                                              .
# diag_1435                                              .
# diag_1436                                              .
# diag_1437                                              .
# diag_1438                                              .
# diag_1440                                              9.172029e-02
# diag_1441                                              .
# diag_1442                                              .
# diag_1443                                              .
# diag_1444                                              .
# diag_1445                                              .
# diag_1446                                              .
# diag_1447                                              .
# diag_1451                                              .
# diag_1453                                              .
# diag_1454                                              .
# diag_1455                                              .
# diag_1456                                              .
# diag_1457                                              .
# diag_1458                                              .
# diag_1459                                              .
# diag_1461                                              .
# diag_1462                                              .
# diag_1464                                              .
# diag_1465                                              .
# diag_1466                                              .
# diag_147                                               .
# diag_1470                                              .
# diag_1473                                              .
# diag_1474                                              .
# diag_1475                                              .
# diag_1478                                              .
# diag_148                                               .
# diag_1480                                              .
# diag_1481                                              .
# diag_1482                                              .
# diag_1483                                              .
# diag_1485                                              .
# diag_1486                                              .
# diag_1487                                              .
# diag_149                                               .
# diag_1490                                              .
# diag_1491                                              4.875572e-02
# diag_1492                                              .
# diag_1493                                              .
# diag_1494                                              .
# diag_1495                                              .
# diag_1496                                              .
# diag_15                                                .
# diag_1501                                              .
# diag_1507                                              .
# diag_1508                                              .
# diag_1510                                              .
# diag_1511                                              .
# diag_1512                                              .
# diag_1513                                              .
# diag_1514                                              .
# diag_1515                                              .
# diag_1516                                              .
# diag_1518                                              .
# diag_1519                                              .
# diag_1521                                              .
# diag_1522                                              .
# diag_1524                                              .
# diag_1526                                              .
# diag_1527                                              .
# diag_1528                                              .
# diag_153                                               .
# diag_1530                                              .
# diag_1531                                              .
# diag_1532                                              .
# diag_1534                                              .
# diag_1535                                              .
# diag_1536                                              .
# diag_1537                                              .
# diag_154                                               .
# diag_1540                                              .
# diag_1541                                              .
# diag_1550                                              .
# diag_1551                                              .
# diag_1552                                              .
# diag_1553                                              .
# diag_1555                                              .
# diag_1556                                              .
# diag_1557                                              .
# diag_1558                                              .
# diag_1560                                              .
# diag_1562                                              .
# diag_1564                                              .
# diag_1565                                              .
# diag_1566                                              .
# diag_1567                                              .
# diag_1568                                              .
# diag_1569                                              .
# diag_1570                                              .
# diag_1571                                              .
# diag_1572                                              .
# diag_1573                                              .
# diag_1574                                              .
# diag_1575                                              .
# diag_1576                                              .
# diag_1577                                              .
# diag_1578                                              .
# diag_1579                                              .
# diag_1580                                              .
# diag_1581                                              .
# diag_1582                                              .
# diag_1584                                              .
# diag_1585                                              .
# diag_1586                                              .
# diag_1588                                              .
# diag_1590                                              .
# diag_1591                                              .
# diag_1592                                              .
# diag_1593                                              .
# diag_1594                                              .
# diag_1595                                              .
# diag_1596                                              .
# diag_1598                                              .
# diag_1599                                              .
# diag_1600                                              .
# diag_1601                                              .
# diag_1604                                              .
# diag_1607                                              .
# diag_1608                                              .
# diag_1611                                              .
# diag_1614                                              .
# diag_1616                                              .
# diag_1617                                              .
# diag_1618                                              .
# diag_1619                                              .
# diag_1620                                              .
# diag_1621                                              .
# diag_1622                                              .
# diag_1623                                              .
# diag_1625                                              .
# diag_1626                                              .
# diag_1633                                              .
# diag_1637                                              .
# diag_1640                                              .
# diag_1642                                              .
# diag_1643                                              .
# diag_1644                                              .
# diag_1646                                              .
# diag_1647                                              .
# diag_1648                                              .
# diag_1652                                              .
# diag_1654                                              .
# diag_1655                                              .
# diag_1656                                              .
# diag_1658                                              .
# diag_1659                                              .
# diag_1660                                              .
# diag_1661                                              .
# diag_1663                                              .
# diag_1664                                              .
# diag_1669                                              .
# diag_1671                                              .
# diag_1680                                              .
# diag_1681                                              .
# diag_1682                                              .
# diag_1685                                              .
# diag_1686                                              .
# diag_1691                                              .
# diag_1692                                              .
# diag_1693                                              .
# diag_17                                                .
# diag_170                                               .
# diag_1705                                              .
# diag_1707                                              .
# diag_1708                                              .
# diag_1709                                              .
# diag_1710                                              .
# diag_1711                                              .
# diag_1714                                              .
# diag_1715                                              .
# diag_1716                                              .
# diag_1717                                              .
# diag_1718                                              .
# diag_1719                                              .
# diag_1721                                              .
# diag_1722                                              .
# diag_1723                                              .
# diag_1724                                              .
# diag_1725                                              .
# diag_1726                                              .
# diag_1727                                              .
# diag_1728                                              .
# diag_1729                                              .
# diag_1730                                              .
# diag_1733                                              .
# diag_1734                                              .
# diag_1736                                              .
# diag_1737                                              .
# diag_1738                                              .
# diag_1745                                              .
# diag_1751                                              .
# diag_1753                                              .
# diag_1756                                              .
# diag_1759                                              .
# diag_178                                               .
# diag_1780                                              .
# diag_1781                                              .
# diag_1782                                              .
# diag_1783                                              .
# diag_1784                                              .
# diag_1785                                              .
# diag_1786                                              .
# diag_1787                                              .
# diag_1788                                              .
# diag_1789                                              .
# diag_179                                               .
# diag_1790                                              .
# diag_1792                                              .
# diag_1794                                              .
# diag_1796                                              .
# diag_1797                                              .
# diag_1799                                              .
# diag_18                                                .
# diag_1800                                              .
# diag_1801                                              .
# diag_1802                                              .
# diag_1805                                              .
# diag_1807                                              .
# diag_1808                                              .
# diag_1810                                              .
# diag_1812                                              .
# diag_1813                                              .
# diag_1814                                              .
# diag_1816                                              .
# diag_182                                               .
# diag_1820                                              .
# diag_1821                                              .
# diag_1822                                              .
# diag_1823                                              .
# diag_1824                                              .
# diag_1825                                              .
# diag_1834                                              .
# diag_1835                                              .
# diag_1839                                              .
# diag_1840                                              .
# diag_1843                                              .
# diag_1844                                              .
# diag_1845                                              .
# diag_1846                                              .
# diag_1847                                              .
# diag_1850                                              .
# diag_1851                                              .
# diag_1852                                              .
# diag_1853                                              .
# diag_1854                                              .
# diag_1860                                              .
# diag_1861                                              .
# diag_1863                                              .
# diag_1864                                              .
# diag_1865                                              .
# diag_1866                                              .
# diag_1867                                              .
# diag_1868                                              .
# diag_1873                                              .
# diag_1878                                              .
# diag_1879                                              .
# diag_188                                               .
# diag_1881                                              .
# diag_1882                                              .
# diag_1883                                              .
# diag_1885                                              .
# diag_1886                                              .
# diag_1890                                              .
# diag_1891                                              .
# diag_1892                                              .
# diag_1893                                              .
# diag_1897                                              .
# diag_19                                                .
# diag_1904                                              .
# diag_1911                                              .
# diag_1913                                              .
# diag_1916                                              .
# diag_1917                                              .
# diag_1920                                              .
# diag_1922                                              .
# diag_1924                                              .
# diag_1928                                              .
# diag_1933                                              .
# diag_1934                                              .
# diag_1935                                              .
# diag_194                                               .
# diag_1942                                              .
# diag_1945                                              .
# diag_1952                                              .
# diag_1955                                              .
# diag_1958                                              .
# diag_1959                                              .
# diag_1962                                              .
# diag_1965                                              .
# diag_1966                                              .
# diag_1967                                              .
# diag_1968                                              .
# diag_1969                                              .
# diag_1970                                              .
# diag_1972                                              .
# diag_1977                                              .
# diag_1983                                              .
# diag_1986                                              .
# diag_1987                                              .
# diag_1989                                              .
# diag_1992                                              .
# diag_1995                                              .
# diag_1996                                              .
# diag_1997                                              .
# diag_1998                                              .
# diag_1999                                              .
# diag_1V45                                              .
# diag_1V53                                              .
# diag_1V54                                              .
# diag_1V55                                              .
# diag_1V56                                              .
# diag_1V57                                              .
# diag_1V58                                              9.700278e-02
# diag_1V60                                              .
# diag_1V67                                              .
# diag_1V71                                              .
# diag_1131                                              .
# diag_1148                                              .
# diag_1173                                              .
# diag_1175                                              .
# diag_1179                                              .
# diag_1195                                              .
# diag_1208                                              .
# diag_1240                                              .
# diag_1250.53                                           .
# diag_127                                               .
# diag_1299                                              .
# diag_1314                                              .
# diag_1318                                              .
# diag_1327                                              .
# diag_1338                                              .
# diag_134                                               .
# diag_1347                                              .
# diag_1354                                              .
# diag_136                                               .
# diag_1360                                              .
# diag_1361                                              .
# diag_1363                                              .
# diag_1370                                              .
# diag_1377                                              .
# diag_1382                                              .
# diag_1385                                              .
# diag_1388                                              .
# diag_1405                                              .
# diag_1417                                              .
# diag_1422                                              .
# diag_1452                                              .
# diag_1463                                              .
# ...
# diag_3E935                                             .
# diag_3E938                                             .
# diag_3E939                                             .
# diag_3E941                                             .
# diag_3E942                                             .
# diag_3E944                                             .
# diag_3E945                                             .
# diag_3E947                                             .
# diag_3E949                                             .
# diag_3E950                                             .
# diag_3E956                                             .
# diag_3E980                                             .
# diag_3missing                                          .
# diag_3V02                                              .
# diag_3V08                                              .
# diag_3V09                                              .
# diag_3V10                                              .
# diag_3V11                                              .
# diag_3V12                                              .
# diag_3V15                                              .
# diag_3V16                                              .
# diag_3V17                                              .
# diag_3V18                                              .
# diag_3V23                                              .
# diag_3V25                                              .
# diag_3V27                                              .
# diag_3V42                                              .
# diag_3V43                                              .
# diag_3V44                                              .
# diag_3V45                                              .
# diag_3V46                                              .
# diag_3V49                                              .
# diag_3V54                                              .
# diag_3V55                                              .
# diag_3V57                                              .
# diag_3V58                                              .
# diag_3V60                                              .
# diag_3V62                                              .
# diag_3V63                                              .
# diag_3V64                                              .
# diag_3V65                                              .
# diag_3V66                                              .
# diag_3V70                                              .
# diag_3V72                                              .
# diag_3123                                              .
# diag_3139                                              .
# diag_3148                                              .
# diag_3151                                              .
# diag_3152                                              .
# diag_3156                                              .
# diag_3164                                              .
# diag_3170                                              .
# diag_3171                                              .
# diag_3172                                              .
# diag_3183                                              .
# diag_3216                                              .
# diag_3225                                              .
# diag_3226                                              .
# diag_3250.21                                           .
# diag_3266                                              .
# diag_3270                                              .
# diag_3283                                              .
# diag_3313                                              .
# diag_3314                                              .
# diag_3318                                              .
# diag_3327                                              .
# diag_3338                                              .
# diag_3345                                              .
# diag_3354                                              .
# diag_3361                                              .
# diag_3365.44                                           .
# diag_3373                                              .
# diag_3374                                              .
# diag_3376                                              .
# diag_3377                                              .
# diag_3381                                              .
# diag_3405                                              .
# diag_3417                                              .
# diag_3421                                              .
# diag_3430                                              .
# diag_3431                                              .
# diag_3451                                              .
# diag_3454                                              .
# diag_3481                                              .
# diag_3484                                              .
# diag_3495                                              .
# diag_3501                                              .
# diag_3508                                              .
# diag_3510                                              .
# diag_3514                                              .
# diag_3516                                              .
# diag_3523                                              .
# diag_3540                                              .
# diag_3550                                              .
# diag_3579                                              .
# diag_3597                                              .
# diag_3603                                              .
# diag_3604                                              .
# diag_3644                                              .
# diag_3649                                              .
# diag_3657                                              .
# diag_3665                                              .
# diag_3674                                              .
# diag_3684                                              .
# diag_3702                                              .
# diag_3704                                              .
# diag_3734                                              .
# diag_3741                                              .
# diag_3753                                              .
# diag_3754                                              .
# diag_3758                                              .
# diag_3795                                              .
# diag_3801                                              .
# diag_3814                                              .
# diag_3821                                              .
# diag_3844                                              .
# diag_3850                                              .
# diag_3852                                              .
# diag_3853                                              .
# diag_3860                                              .
# diag_3872                                              .
# diag_3879                                              .
# diag_3880                                              .
# diag_3910                                              .
# diag_3911                                              .
# diag_3912                                              .
# diag_3917                                              .
# diag_3930                                              .
# diag_3933                                              .
# diag_3948                                              .
# diag_3962                                              .
# diag_3991                                              .
# diag_3E813                                             .
# diag_3E815                                             .
# diag_3E822                                             .
# diag_3E828                                             .
# diag_3E853                                             .
# diag_3E881                                             .
# diag_3E886                                             .
# diag_3E892                                             .
# diag_3E901                                             .
# diag_3E906                                             .
# diag_3E917                                             .
# diag_3E919                                             .
# diag_3E922                                             .
# diag_3E924                                             .
# diag_3E936                                             .
# diag_3V01                                              .
# diag_3V03                                              .
# diag_3V13                                              .
# diag_3V14                                              .
# diag_3V53                                              .
# diag_3V61                                              .
# diag_3V85                                              .
# diag_3V86                                              .
# diag_3141                                              .
# diag_3163                                              .
# diag_3217                                              .
# diag_3223                                              .
# diag_3233                                              .
# diag_3268                                              .
# diag_3299                                              .
# diag_3370                                              .
# diag_3388                                              .
# diag_3463                                              .
# diag_349                                               .
# diag_3500                                              .
# diag_357                                               .
# diag_3588                                              .
# diag_3622                                              .
# diag_3669                                              .
# diag_3706                                              .
# diag_3720                                              .
# diag_3750                                              .
# diag_3834                                              .
# diag_3875                                              .
# diag_3877                                              .
# diag_3909                                              .
# diag_3913                                              .
# diag_3928                                              .
# diag_3943                                              .
# diag_3969                                              .
# diag_3971                                              .
# diag_3E818                                             .
# diag_3E825                                             .
# diag_3E854                                             .
# diag_3E900                                             .
# diag_3E912                                             .
# diag_3V07                                              .
# max_glu_serum.300                                      .
# max_glu_serumNone                                      .
# max_glu_serumNorm                                      .
# A1Cresult.8                                            .
# A1CresultNone                                          2.382453e-02
# A1CresultNorm                                          .
# metforminNo                                            3.877788e-04
# metforminSteady                                        .
# metforminUp                                            .
# repaglinideNo                                          .
# repaglinideSteady                                      .
# repaglinideUp                                          .
# nateglinideSteady                                      .
# nateglinideUp                                          .
# nateglinideDown                                        .
# chlorpropamideSteady                                   .
# chlorpropamideUp                                       .
# glimepirideNo                                          .
# glimepirideSteady                                      .
# glimepirideUp                                          .
# glipizideNo                                            .
# glipizideSteady                                        .
# glipizideUp                                            .
# glyburideNo                                            .
# glyburideSteady                                        .
# glyburideUp                                            .
# tolbutamideSteady                                      .
# pioglitazoneNo                                         .
# pioglitazoneSteady                                     .
# pioglitazoneUp                                         .
# rosiglitazoneNo                                        .
# rosiglitazoneSteady                                    5.141611e-04
# rosiglitazoneUp                                        .
# acarboseSteady                                         .
# acarboseUp                                             .
# miglitolSteady                                         .
# tolazamideSteady                                       .
# insulinNo                                              .
# insulinSteady                                          .
# insulinUp                                              .
# glyburide_metforminNo                                  .
# glyburide_metforminSteady                              .
# glyburide_metforminUp                                  .
# glipizide_metforminSteady                              .
# changeNo                                               .
# diabetesMedYes                                         1.754191e-01

# %%
# Do cross validation with the Input Data
cvfit = cv.glmnet(x=dataMatrix, y=label, alpha=1, family='binomial')
# plot(cvfit)
